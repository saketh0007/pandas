# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data : 1 'House Rental Data'

# %%
house_rental = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt')
house_rental.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %% [markdown]
# ## 1. Load rental data with first column as index column (Solved)

# %%
house_rental = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt',index_col = 'Unnamed: 0')
house_rental.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %% [markdown]
# ### 2. Find all houses which has more than 2 bedroom and price less than 50k

# %%
house_rental[(house_rental['Bedroom']>3) & (house_rental['Price'] < 50000)].head()
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 13   1352.040      9          19        4            2         2  39000
# 62    889.500      2           4        4            1         1  32000
# 78   1522.824      5          12        4            2         2  40000
# 81   1558.404      5           7        4            2         2  48800
# 137  1921.320      4           7        4            2         2  48000

# %%
#renaming the column
house_rental.rename(columns = {'Living.Room':'living_room'},inplace = True)

# %%
house_rental.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  living_room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %% [markdown]
# ### 3. Find all houses which has more than 3 bedroom and price less than 50k. Update their price with 60k

# %%
house_rental.loc[(house_rental['Bedroom'] > 3) & (house_rental['Price'] < 50000),'Price'] = 60000
house_rental[(house_rental['Price']) == 60000].head()
# Out:
#         Sqft  Floor  TotalFloor  Bedroom  living_room  Bathroom  Price
# 13  1352.040      9          19        4            2         2  60000
# 38   768.528      4           4        3            2         2  60000
# 62   889.500      2           4        4            1         1  60000
# 78  1522.824      5          12        4            2         2  60000
# 81  1558.404      5           7        4            2         2  60000

# %% [markdown]
# ###
# 4. Find no of house who's price is updated in previous question.

# %%
house_rental = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt')
price60 = house_rental.apply(lambda x: True if ((x['Bedroom']>3) & (x['Price']<50000)) else False, axis=1)
count = len(price60[price60==True].index)
count
# Out:
# 23

# %% [markdown]
# ### 5. Find average price of house.

# %%
house_rental.Price.mean()
# Out:
# 61986.82325581396

# %% [markdown]
# ### 6. Find average price of house respective to bedroom.
# example : avg price of house of 1 bedroom then 2 ...so on

# %%
bedroom = house_rental['Bedroom'].max()
bedroom
for i in range  (1,bedroom+1):
    h = house_rental[(house_rental['Bedroom']==i)]
    avg_price = h['Price'].mean()
    print(f'Average price of house with {i} Bedroom : {avg_price}')
# Out:
# Average price of house with 1 Bedroom : 35549.086956521736
# Average price of house with 2 Bedroom : 47131.68944099379
# Average price of house with 3 Bedroom : 65030.94979079498
# Average price of house with 4 Bedroom : 77745.43478260869
# Average price of house with 5 Bedroom : 117000.0
# Average price of house with 6 Bedroom : 180000.0
# Average price of house with 7 Bedroom : 180000.0

# %% [markdown]
# ###

# %% [markdown]
# ### 7. Find details of house whose price is highest.

# %%
price = house_rental['Price'].max()
house_rental[house_rental['Price'] == price]
# Out:
#      Unnamed: 0     Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 286         289  3504.63     13          14        2            2         2
#
#       Price
# 286  250000

# %% [markdown]
# ### 8. Sort the given data by price in ascending order

# %%
sorted = house_rental.sort_values("Price",axis = 0 , ascending = True)
sorted.head()
# Out:
#      Unnamed: 0    Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 609         613  996.24      4           5        3            2         1
# 404         408  604.86      5           5        2            0         1
# 620         624  711.60      1           1        3            1         1
# 371         375  426.96      9          12        1            0         1
# 273         276  533.70      7          12        1            1         1
#
#      Price
# 609   6100
# 404  11900
# 620  12000
# 371  13000
# 273  17000

# %% [markdown]
# ### 9. Display all details of house with 1 bedroom first then 2 bedroom.. and so on.
# Note use Groupby then describe

# %%
h = house_rental.groupby("Bedroom")
h.describe()
# Out:
#         Bathroom                                               Floor  \
#            count      mean       std  min  25%  50%  75%  max  count
# Bedroom
# 1           69.0  1.043478  0.267603  1.0  1.0  1.0  1.0  3.0   69.0
# 2          161.0  1.385093  0.513105  1.0  1.0  1.0  2.0  3.0  161.0
# 3          239.0  1.970711  0.470986  0.0  2.0  2.0  2.0  4.0  239.0
# 4          161.0  2.198758  0.568110  1.0  2.0  2.0  2.0  5.0  161.0
# 5           13.0  3.000000  1.154701  1.0  2.0  3.0  4.0  4.0   13.0
# 6            1.0  5.000000       NaN  5.0  5.0  5.0  5.0  5.0    1.0
# 7            1.0  4.000000       NaN  4.0  4.0  4.0  4.0  4.0    1.0
#
#                     ...   TotalFloor       Unnamed: 0                          \
#               mean  ...          75%   max      count        mean         std
# Bedroom             ...
# 1         6.304348  ...         14.0  26.0       69.0  338.536232  182.186603
# 2         6.024845  ...         13.0  21.0      161.0  313.378882  179.492198
# 3         5.640167  ...         14.0  38.0      239.0  336.564854  195.087017
# 4         5.689441  ...         14.0  27.0      161.0  315.534161  184.792993
# 5        10.769231  ...         21.0  24.0       13.0  267.230769  179.004262
# 6         7.000000  ...         21.0  21.0        1.0  576.000000         NaN
# 7        15.000000  ...         19.0  19.0        1.0  625.000000         NaN
#
#
#            min    25%    50%    75%    max
# Bedroom
# 1          8.0  214.0  349.0  490.0  646.0
# 2          1.0  172.0  316.0  461.0  637.0
# 3          4.0  164.5  341.0  515.5  648.0
# 4          2.0  143.0  308.0  475.0  643.0
# 5         21.0  108.0  303.0  360.0  570.0
# 6        576.0  576.0  576.0  576.0  576.0
# 7        625.0  625.0  625.0  625.0  625.0
#
# [7 rows x 56 columns]

# %% [markdown]
# ### 10. Display all details of each house with 1 bedroom first then 2 bedroom.. and so on.

# %%
h = house_rental.groupby(['Bedroom','Price'])
h.describe()
# Out:
#                Bathroom                                                Floor  \
#                   count      mean       std  min   25%  50%   75%  max count
# Bedroom Price
# 1       13000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         17000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         19000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         20000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         22000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         23000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         23800       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         24800       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         24888       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         25000       5.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   5.0
#         26000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         27500       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         28000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         28800       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         29000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         29500       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         30000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         31000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         33000       2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   2.0
#         34000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         35000       5.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   5.0
#         36000       6.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   6.0
#         38000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         38800       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         39000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         40000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         42000       3.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   3.0
#         43000       3.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   3.0
#         45000       4.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0   4.0
#         47999       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
# ...                 ...       ...       ...  ...   ...  ...   ...  ...   ...
# 4       98000      10.0  2.300000  0.483046  2.0  2.00  2.0  2.75  3.0  10.0
#         99999       1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         100000     11.0  2.272727  0.467099  2.0  2.00  2.0  2.50  3.0  11.0
#         105000      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         108000      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         110000      4.0  2.000000  0.000000  2.0  2.00  2.0  2.00  2.0   4.0
#         120000      2.0  5.000000  0.000000  5.0  5.00  5.0  5.00  5.0   2.0
#         129999      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         130000      2.0  4.500000  0.707107  4.0  4.25  4.5  4.75  5.0   2.0
#         135000      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         138000      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0   1.0
#         138888      3.0  2.000000  0.000000  2.0  2.00  2.0  2.00  2.0   3.0
#         145000      1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0   1.0
#         148000      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         149999      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
#         150000      3.0  2.333333  0.577350  2.0  2.00  2.0  2.50  3.0   3.0
#         160000      1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0   1.0
# 5       55000       1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0   1.0
#         56000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         60000       1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0   1.0
#         80000       1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0   1.0
#         89000       1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0   1.0
#         100000      2.0  3.000000  1.414214  2.0  2.50  3.0  3.50  4.0   2.0
#         140000      2.0  4.000000  0.000000  4.0  4.00  4.0  4.00  4.0   2.0
#         145000      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0   1.0
#         170000      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0   1.0
#         180000      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0   1.0
#         206000      1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0   1.0
# 6       180000      1.0  5.000000       NaN  5.0  5.00  5.0  5.00  5.0   1.0
# 7       180000      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0   1.0
#
#                            ...   TotalFloor       Unnamed: 0              \
#                      mean  ...          75%   max      count        mean
# Bedroom Price              ...
# 1       13000    9.000000  ...        12.00  12.0        1.0  375.000000
#         17000    4.500000  ...        12.00  12.0        2.0  360.000000
#         19000   22.000000  ...        26.00  26.0        1.0  369.000000
#         20000   13.000000  ...        14.00  14.0        1.0  532.000000
#         22000    8.500000  ...        11.50  14.0        2.0  244.000000
#         23000    5.000000  ...        13.00  13.0        1.0   66.000000
#         23800    3.000000  ...        12.00  12.0        1.0  206.000000
#         24800    4.000000  ...        10.00  10.0        1.0  645.000000
#         24888    4.000000  ...         7.00   7.0        1.0  349.000000
#         25000    7.000000  ...        14.00  16.0        5.0  213.400000
#         26000   10.000000  ...        12.75  13.0        2.0  289.000000
#         27500    5.500000  ...        12.25  14.0        2.0   67.000000
#         28000    4.500000  ...         8.75  10.0        2.0  464.000000
#         28800    7.000000  ...         7.00   7.0        1.0  579.000000
#         29000    2.000000  ...        12.00  12.0        1.0  416.000000
#         29500    5.000000  ...        11.00  11.0        1.0  355.000000
#         30000    8.000000  ...        12.00  12.0        1.0  612.000000
#         31000    7.000000  ...        13.25  14.0        2.0  302.500000
#         33000    4.000000  ...         6.75   7.0        2.0  344.500000
#         34000    7.000000  ...         7.00   7.0        1.0  423.000000
#         35000    3.600000  ...        12.00  12.0        5.0  379.200000
#         36000    6.500000  ...        14.00  14.0        6.0  328.666667
#         38000    2.000000  ...         9.00   9.0        1.0  194.000000
#         38800    6.000000  ...        14.00  14.0        1.0  490.000000
#         39000    6.000000  ...        14.00  14.0        1.0  367.000000
#         40000    3.000000  ...         6.00   6.0        1.0  535.000000
#         42000    6.333333  ...         9.00   9.0        3.0  337.666667
#         43000   11.000000  ...        14.00  14.0        3.0  357.666667
#         45000    8.750000  ...        10.25  14.0        4.0  421.500000
#         47999   10.000000  ...        14.00  14.0        1.0  562.000000
# ...                   ...  ...          ...   ...        ...         ...
# 4       98000    5.600000  ...        12.00  25.0       10.0  363.000000
#         99999    2.000000  ...         7.00   7.0        1.0  114.000000
#         100000   3.545455  ...        14.00  17.0       11.0  368.181818
#         105000   2.000000  ...        14.00  14.0        1.0  474.000000
#         108000   2.000000  ...        14.00  14.0        1.0  484.000000
#         110000  10.500000  ...        25.00  25.0        4.0  405.500000
#         120000   4.000000  ...         7.00   7.0        2.0  323.000000
#         129999   5.000000  ...        12.00  12.0        1.0  606.000000
#         130000   4.000000  ...         7.00   7.0        2.0  136.000000
#         135000  14.000000  ...        18.00  18.0        1.0  471.000000
#         138000  16.000000  ...        21.00  21.0        1.0  544.000000
#         138888   5.000000  ...        12.00  12.0        3.0  483.666667
#         145000  21.000000  ...        24.00  24.0        1.0   28.000000
#         148000  11.000000  ...        12.00  12.0        1.0    6.000000
#         149999   5.000000  ...         6.00   6.0        1.0  118.000000
#         150000   4.666667  ...        18.50  21.0        3.0  396.666667
#         160000   3.000000  ...         9.00   9.0        1.0  245.000000
# 5       55000    7.000000  ...        16.00  16.0        1.0  360.000000
#         56000    3.000000  ...        12.00  12.0        1.0  340.000000
#         60000    1.000000  ...         7.00   7.0        1.0  570.000000
#         80000   12.000000  ...        12.00  12.0        1.0  108.000000
#         89000   12.000000  ...        12.00  12.0        1.0  511.000000
#         100000   8.500000  ...        17.00  21.0        2.0  346.000000
#         140000  19.000000  ...        21.00  21.0        2.0   81.500000
#         145000  21.000000  ...        24.00  24.0        1.0   41.000000
#         170000  19.000000  ...        21.00  21.0        1.0  331.000000
#         180000   1.000000  ...         6.00   6.0        1.0   55.000000
#         206000   9.000000  ...        13.00  13.0        1.0  303.000000
# 6       180000   7.000000  ...        21.00  21.0        1.0  576.000000
# 7       180000  15.000000  ...        19.00  19.0        1.0  625.000000
#
#
#                        std    min     25%    50%     75%    max
# Bedroom Price
# 1       13000          NaN  375.0  375.00  375.0  375.00  375.0
#         17000   118.793939  276.0  318.00  360.0  402.00  444.0
#         19000          NaN  369.0  369.00  369.0  369.00  369.0
#         20000          NaN  532.0  532.00  532.0  532.00  532.0
#         22000   175.362482  120.0  182.00  244.0  306.00  368.0
#         23000          NaN   66.0   66.00   66.0   66.00   66.0
#         180000         NaN   55.0   55.00   55.0   55.00   55.0
#         206000         NaN  303.0  303.00  303.0  303.00  303.0
# 6       180000         NaN  576.0  576.00  576.0  576.00  576.0
# 7       180000         NaN  625.0  625.00  625.0  625.00  625.0
#
# [262 rows x 48 columns]

# %%
hc_df = pd.read_excel('C:\\Users\\saket\\Downloads\\HealthCareData-1.xlsx')
hc_df.head()
# Out:
#    S.NO  Age  Gender Place(location where the patient lives)  \
# 0     1   55    male                                   rural
# 1     2   55    male                                   rural
# 2     3   55    male                                   rural
# 3     4   55    male                                   rural
# 4     5   55  female                                   rural
#
#    Duration of alcohol consumption(years)  \
# 0                                      12
# 1                                      12
# 2                                      12
# 3                                      12
# 4                                      12
#
#    Quantity of alcohol consumption (quarters/day) Type of alcohol consumed  \
# 0                                               2           branded liquor
# 1                                               2           branded liquor
# 2                                               2           branded liquor
# 3                                               2           branded liquor
# 4                                               2           branded liquor
#
#   Hepatitis B infection Hepatitis C infection Diabetes Result  \
# 0              negative              negative             YES
# 1              negative              negative             YES
# 2              negative              negative             YES
# 3              negative              negative              NO
# 4              negative              negative             YES
#
#                                     ...                                     \
# 0                                   ...
# 1                                   ...
# 2                                   ...
# 3                                   ...
# 4                                   ...
#
#   Indirect     (mg/dl) Total Protein     (g/dl) Albumin   (g/dl)  \
# 0                  3.0                      6.0              3.0
# 1                  3.0                      6.0              3.0
# 2                  3.0                      6.0              3.0
# 3                  3.0                      6.0              3.0
# 4                  3.0                      6.0              3.0
#
#    Globulin  (g/dl) A/G Ratio AL.Phosphatase      (U/L)  SGOT/AST      (U/L)  \
# 0               4.0      0.75                     150.0                   56
# 1               4.0      0.75                     150.0                   56
# 2               4.0      0.75                     150.0                   56
# 3               4.0      0.75                     150.0                   56
# 4               4.0      0.75                     150.0                   56
#
#    SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)  \
# 0              34                                  YES
# 1              34                                  YES
# 2              34                                  YES
# 3              34                                  YES
# 4              34                                  YES
#
#    Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 1. Display all the information respective to gender

# %%
gender = hc_df.groupby(['Gender','Age'])
gender.describe()
# Out:
#                 AL.Phosphatase      (U/L)                                \
#                                     count        mean        std    min
# Gender      Age
# female      32                        8.0  119.000000   0.000000  119.0
#             35                        8.0   76.000000   0.000000   76.0
#             36                        2.0  108.000000  45.254834   76.0
#             37                        3.0  116.000000  34.641016   76.0
#             38                       12.0  104.500000  16.670606   96.0
#             40                        2.0  118.000000  31.112698   96.0
#             42                        9.0  100.333333   7.000000   98.0
#             43                        2.0  139.000000  57.982756   98.0
#             47                        2.0  156.000000   0.000000  156.0
#             48                       11.0  178.818182  27.102834  124.0
#             49                       12.0  153.250000   4.070403  151.0
#             50                        6.0  136.000000  30.006666  114.0
#             51                       10.0  102.000000   0.000000  102.0
#             52                        3.0  129.333333  44.286943   98.0
#             53                        1.0  152.000000        NaN  152.0
#             54                        2.0  120.500000  12.020815  112.0
#             55                       19.0  145.578947   6.058197  140.0
#             56                       20.0  162.000000  45.143047  118.0
#             57                        2.0  156.500000   0.707107  156.0
#             58                       10.0  160.400000   5.561774  148.0
#             60                       10.0  141.700000   7.273239  121.0
#             59   1.414214e+00  4.0  4.500  5.00  5.500  6.0
#             60   1.239489e+00  4.0  4.075  6.00  7.000  7.4
#             61   0.000000e+00  4.0  4.000  4.00  4.000  4.0
#             62   8.708970e-01  3.0  3.000  4.00  5.000  5.0
#             63   9.420555e-16  5.6  5.600  5.60  5.600  5.6
#             64   1.296499e+00  4.0  8.300  8.30  8.300  8.3
#             65   0.000000e+00  6.0  6.000  6.00  6.000  6.0
#             67            NaN  5.6  5.600  5.60  5.600  5.6
#             68            NaN  NaN    NaN   NaN    NaN  NaN
#             70   9.362223e-16  5.1  5.100  5.10  5.100  5.1
# transgender 47   0.000000e+00  6.5  6.500  6.50  6.500  6.5
#
# [64 rows x 208 columns]

# %% [markdown]
# ### 2. Find all the male who is consuming alcohal more than 5 years and has diabetes result positive.¶

# %%
h = hc_df[(hc_df['Gender'] == 'male') & (hc_df['Duration of alcohol consumption(years)'] > 5)]
h.head()
# Out:
#    S.NO  Age Gender Place(location where the patient lives)  \
# 0     1   55   male                                   rural
# 1     2   55   male                                   rural
# 2     3   55   male                                   rural
# 3     4   55   male                                   rural
# 5     6   55   male                                   urban
#
#    Duration of alcohol consumption(years)  \
# 0                                      12
# 1                                      12
# 2                                      12
# 3                                      12
# 5                                      12
#
#    Quantity of alcohol consumption (quarters/day) Type of alcohol consumed  \
# 0                                               2           branded liquor
# 1                                               2           branded liquor
# 2                                               2           branded liquor
# 3                                               2           branded liquor
# 5                                               2           branded liquor
#
#   Hepatitis B infection Hepatitis C infection Diabetes Result  \
# 0              negative              negative             YES
# 1              negative              negative             YES
# 2              negative              negative             YES
# 3              negative              negative              NO
# 5              negative              negative             YES
#
#                                     ...                                     \
# 0                                   ...
# 1                                   ...
# 2                                   ...
# 3                                   ...
# 5                                   ...
#
#   Indirect     (mg/dl) Total Protein     (g/dl) Albumin   (g/dl)  \
# 0                  3.0                      6.0              3.0
# 1                  3.0                      6.0              3.0
# 2                  3.0                      6.0              3.0
# 3                  3.0                      6.0              3.0
# 5                  3.0                      6.0              3.0
#
#    Globulin  (g/dl) A/G Ratio AL.Phosphatase      (U/L)  SGOT/AST      (U/L)  \
# 0               4.0      0.75                     150.0                   56
# 1               4.0      0.75                     150.0                   56
# 2               4.0      0.75                     150.0                   56
# 3               4.0      0.75                     150.0                   56
# 5               4.0      0.75                     150.0                   56
#
#    SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)  \
# 0              34                                  YES
# 1              34                                  YES
# 2              34                                  YES
# 3              34                                  YES
# 5              34                                  YES
#
#    Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 5                                                YES
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 3. Find where more people consume alcohol in rural or urban?

# %%
rural = hc_df.apply(lambda x: True if x['Place(location where the patient lives)']=='rural' else False, axis=1)
count_rural = len(rural[rural==True].index)
urban = hc_df.apply(lambda x: True if x['Place(location where the patient lives)']=='urban' else False, axis=1)
count_urban = len(urban[urban==True].index)
if count_urban>count_rural:
    print("Urban's people consume more alcohal than rural's people")
else:
    print("Rural's people consume more alcohal than urban's people")
# Out:
# Rural's people consume more alcohal than urban's people

# %% [markdown]
# ### 4. Find average age of male and female who consume alcohol.

# %%
female = hc_df[(hc_df['Gender']=='female')]
print(f'Female average age: {female.Age.mean()}')
male = hc_df[(hc_df['Gender']=='male')]
print(f'Male average age: {male.Age.mean()}')
# Out:
# Female average age: 52.54358974358974
# Male average age: 50.115020297699594

# %% [markdown]
# ### 5. Display distribution for different type of alcohol

# %%
d = hc_df.groupby(['Type of alcohol consumed'])

# %%
d.describe()
# Out:
#                          AL.Phosphatase      (U/L)                         \
#                                              count        mean        std
# Type of alcohol consumed
#  branded liquor                                1.0  100.000000        NaN
# both                                         287.0  138.965157  26.314375
# branded liquor                               183.0  128.874317  27.078245
# country liquor                               469.0  130.076759  27.676676
#
#                                                                Age             \
#                             min    25%    50%    75%    max  count       mean
# Type of alcohol consumed
#  branded liquor           100.0  100.0  100.0  100.0  100.0    1.0  46.000000
# both                      100.0  118.0  139.0  156.0  191.0  288.0  50.909722
# branded liquor             70.0  111.0  115.0  148.0  196.0  183.0  50.224044
# country liquor             56.0  110.0  129.0  150.0  206.0  478.0  50.631799
#
#                          ...  Total Count          Total Protein     (g/dl)  \
#                          ...          75%      max                    count
# Type of alcohol consumed ...
#  branded liquor          ...       7000.0   7000.0                      1.0
# both                     ...      11504.0  12410.0                    227.0
# branded liquor           ...       8200.0  12300.0                    183.0
# country liquor           ...       9100.0  13000.0                    478.0
#
#
#                               mean       std  min  25%  50%  75%  max
# Type of alcohol consumed
#  branded liquor           5.000000       NaN  5.0  5.0  5.0  5.0  5.0
# both                      5.503524  1.436837  3.0  4.0  6.1  6.4  8.0
# branded liquor            4.880328  1.285056  3.0  4.0  4.6  6.0  7.4
# country liquor            5.904603  1.144937  2.5  5.0  6.0  6.6  8.3
#
# [4 rows x 216 columns]

# %% [markdown]
# ### 6. Display average age of people who has diabetes positive.

# %%
diabetes = hc_df[(hc_df['Diabetes Result'] == 'YES')]

# %%
print(f"average age :",diabetes.Age.mean())
# Out:
# average age : 50.68006182380216

# %% [markdown]
# ### 7. Find is there any missing value of age in given data.

# %%
diabetes[diabetes.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [S.NO, Age, Gender, Place(location where the patient lives), Duration of alcohol consumption(years), Quantity of alcohol consumption (quarters/day), Type of alcohol consumed, Hepatitis B infection, Hepatitis C infection, Diabetes Result, Blood pressure (mmhg), Obesity, Family history of cirrhosis/ hereditary, TCH, TG, LDL, HDL, Hemoglobin  (g/dl), PCV  (%), RBC  (million cells/microliter), MCV   (femtoliters/cell), MCH  (picograms/cell), MCHC  (grams/deciliter), Total Count, Polymorphs  (%) , Lymphocytes  (%), Monocytes   (%), Eosinophils   (%), Basophils  (%), Platelet Count  (lakhs/mm), Total Bilirubin    (mg/dl), Direct    (mg/dl), Indirect     (mg/dl), Total Protein     (g/dl), Albumin   (g/dl), Globulin  (g/dl), A/G Ratio, AL.Phosphatase      (U/L), SGOT/AST      (U/L), SGPT/ALT (U/L), USG Abdomen (diffuse liver or  not), Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# ### 8. If gender is male and age is less than 35 then change diabetes result to NO .

# %%
hc_df.loc[((hc_df['Gender']=='female') & (hc_df['Age']<35)),"Diabetes Result"]='NO'
hc_df[hc_df['Age']<35]
# Out:
#      S.NO  Age  Gender Place(location where the patient lives)  \
# 743   744   32  female                                   urban
# 753   754   32  female                                   urban
# 758   759   32  female                                   urban
# 763   764   32  female                                   urban
# 768   769   32  female                                     NaN
# 773   774   32  female                                   rural
# 778   779   32  female                                   urban
# 783   784   32  female                                   urban
#
#      Duration of alcohol consumption(years)  \
# 743                                      14
# 753                                      14
# 758                                      14
# 763                                      14
# 768                                      14
# 773                                      14
# 778                                      14
# 783                                      14
#
#      Quantity of alcohol consumption (quarters/day) Type of alcohol consumed  \
# 743                                               2           branded liquor
# 753                                               2           branded liquor
# 758                                               2           branded liquor
# 763                                               2           branded liquor
# 768                                               2           branded liquor
# 773                                               2           branded liquor
# 778                                               2                     both
# 783                                               2           branded liquor
#
#     Hepatitis B infection Hepatitis C infection Diabetes Result  \
# 743              negative              negative              NO
# 753              negative              negative              NO
# 758              Positive              Positive              NO
# 763              negative              negative              NO
# 768              negative              negative              NO
# 773              negative              negative              NO
# 778              negative              negative              NO
# 783              negative              negative              NO
#
#                                       ...                                     \
# 743                                   ...
# 753                                   ...
# 758                                   ...
# 763                                   ...
# 768                                   ...
# 773                                   ...
# 778                                   ...
# 783                                   ...
#
#     Indirect     (mg/dl) Total Protein     (g/dl) Albumin   (g/dl)  \
# 743                  1.2                      5.8              3.2
# 753                  1.2                      5.8              3.2
# 758                  1.2                      5.8              3.2
# 763                  1.2                      5.8              3.2
# 768                  1.2                      5.8              3.2
# 773                  1.2                      5.8              3.2
# 778                  1.2                      5.8              3.2
# 783                  1.2                      5.8              3.2
#
#      Globulin  (g/dl) A/G Ratio AL.Phosphatase      (U/L)  \
# 743               2.6     1.5:1                     119.0
# 753               2.6     1.5:1                     119.0
# 758               2.6       NaN                     119.0
# 763               2.6     1.5:1                     119.0
# 768               2.6     1.5:1                     119.0
# 773               2.6     1.5:1                     119.0
# 778               2.6     1.5:1                     119.0
# 783               2.6     1.5:1                     119.0
#
#      SGOT/AST      (U/L)  SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)  \
# 743                   54              46                                  YES
# 753                   54              46                                  YES
# 758                   54              46                                  YES
# 763                   54              46                                  YES
# 768                   54              46                                  YES
# 773                   54              46                                  YES
# 778                   54              46                                  YES
# 783                   54              46                                  YES
#
#      Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# 743                                                YES
# 753                                                YES
# 758                                                YES
# 763                                                YES
# 768                                                YES
# 773                                                YES
# 778                                                YES
# 783                                                YES
#
# [8 rows x 42 columns]

# %% [markdown]
# ### 9. Find all record where Place is missing.

# %%
hc_df.columns
hc_df.rename(columns={"Place(location where the patient lives)":"Place"},inplace=True)
hc_df[hc_df.Place.isnull()]
# Out:
#      S.NO  Age  Gender Place  Duration of alcohol consumption(years)  \
# 190   191   50    male   NaN                                      28
# 198   199   50    male   NaN                                      28
# 199   200   44    male   NaN                                      25
# 245   246   42    male   NaN                                      20
# 295   296   46    male   NaN                                      18
# 297   298   46    male   NaN                                      16
# 327   328   48    male   NaN                                      18
# 331   332   57    male   NaN                                      27
# 334   335   50    male   NaN                                      20
# 357   358   48    male   NaN                                      18
# 360   361   48    male   NaN                                      25
# 375   376   56  female   NaN                                      32
# 376   377   60    male   NaN                                      36
# 377   378   56  female   NaN                                      32
# 378   379   60    male   NaN                                      36
# 391   392   56  female   NaN                                      32
# 392   393   60    male   NaN                                      36
# 393   394   56  female   NaN                                      32
# 394   395   60    male   NaN                                      36
# 395   396   55  female   NaN                                      20
# 396   397   52    male   NaN                                      30
# 397   398   78  female   NaN                                      40
# 398   399   42    male   NaN                                      18
# 399   400   55    male   NaN                                      22
# 400   401   35  female   NaN                                      16
# 401   402   62    male   NaN                                      30
# 402   403   38  female   NaN                                      16
# 403   404   56    male   NaN                                      22
# 404   405   38    male   NaN                                      24
# 405   406   46    male   NaN                                      22
# ..    ...  ...     ...   ...                                     ...
# 682   683   60    male   NaN                                      30
# 683   684   42  female   NaN                                      12
# 684   685   50    male   NaN                                      25
# 685   686   42    male   NaN                                      22
# 686   687   62    male   NaN                                      30
# 687   688   45    male   NaN                                      10
# 688   689   42    male   NaN                                      20
# 689   690   42    male   NaN                                      15
# 690   691   60    male   NaN                                      30
# 691   692   42    male   NaN                                      12
# 692   693   50    male   NaN                                      25
# 693   694   42    male   NaN                                      22
# 694   695   62    male   NaN                                      30
# 700   701   57    male   NaN                                      25
# 709   710   46    male   NaN                                      18
# 730   731   54    male   NaN                                      20
# 731   732   58    male   NaN                                      28
# 732   733   54    male   NaN                                      18
# 768   769   32  female   NaN                                      14
# 770   771   50    male   NaN                                      14
# 804   805   48    male   NaN                                      20
# 812   813   48    male   NaN                                      20
# 833   834   42    male   NaN                                      10
# 841   842   46    male   NaN                                      10
# 842   843   42    male   NaN                                      10
# 877   878   38    male   NaN                                      10
# 911   912   50    male   NaN                                      20
# 917   918   50  female   NaN                                      20
# 927   928   50    male   NaN                                      18
# 929   930   50    male   NaN                                      20
#
#      Quantity of alcohol consumption (quarters/day) Type of alcohol consumed  \
# 190                                               3                     both
# 198                                               3                     both
# 199                                               3                     both
# 245                                               1           country liquor
# 295                                               2           country liquor
# 297                                               2           country liquor
# 327                                               3           country liquor
# 331                                               2           country liquor
# 334                                               3           branded liquor
# 357                                               2           country liquor
# 360                                               2           country liquor
# 375                                               1           country liquor
# 376                                               2                     both
# 377                                               1           country liquor
# 378                                               2                     both
# 391                                               1           country liquor
# 392                                               2                     both
# 393                                               1           country liquor
# 394                                               2                     both
# 395                                               2           country liquor
# 396                                               2           country liquor
# 397                                               4           country liquor
# 398                                               2           country liquor
# 399                                               2                     both
# 400                                               2           country liquor
# 401                                               2           country liquor
# 402                                               1           country liquor
# 403                                               2           branded liquor
# 404                                               2           country liquor
# 405                                               2                     both
# ..                                              ...                      ...
# 682                                               3                     both
# 683                                               4           country liquor
# 684                                               2           branded liquor
# 685                                               3                     both
# 686                                               3           branded liquor
# 687                                               2           branded liquor
# 688                                               4           branded liquor
# 689                                               2           branded liquor
# 690                                               3                     both
# 691                                               4           country liquor
# 692                                               1                     both
# 693                                               3                     both
# 694                                               3           branded liquor
# 700                                               1           country liquor
# 709                                               2           country liquor
# 730                                               2           country liquor
# 731                                               2           branded liquor
# 732                                               2           country liquor
# 768                                               2           branded liquor
# 770                                               2           country liquor
# 804                                               2           branded liquor
# 812                                               2           branded liquor
# 833                                               3           branded liquor
# 841                                               3           branded liquor
# 842                                               3           branded liquor
# 877                                               3                     both
# 911                                               3                     both
# 917                                               3                     both
# 927                                               3                     both
# 929                                               3                     both
#
#     Hepatitis B infection Hepatitis C infection Diabetes Result  \
# 190              Positive              Positive             YES
# 198              Positive              Positive             YES
# 199              Positive              Positive             YES
# 245              negative              negative             YES
# 295              negative              negative             YES
# 297              negative              negative             YES
# 327              negative              negative             YES
# 331              negative              negative             YES
# 334              negative              negative             YES
# 357              negative              negative             YES
# 360              negative              negative             YES
# 375              Positive              Positive              NO
# 376              negative              negative              NO
# 377              Positive              Positive              NO
# 378              negative              negative             YES
# 391              Positive              Positive              NO
# 392              negative              negative              NO
# 393              Positive              Positive              NO
# 394              negative              negative              NO
# 395              Positive              Positive              NO
# 396              negative              negative             YES
# 397              negative              negative             YES
# 398              negative              negative             YES
# 399              negative              negative              NO
# 400              negative              negative              NO
# 401              negative              negative              NO
# 402              negative              negative              NO
# 403              negative              negative              NO
# 404              negative              negative              NO
# 405              negative              negative              NO
# ..                    ...                   ...             ...
# 682              negative              negative             YES
# 683              negative              negative              NO
# 684              Positive              Positive             YES
# 685              negative              negative              NO
# 686              negative              negative             YES
# 687              negative              negative              NO
# 688              negative              negative              NO
# 689              Positive              Positive              NO
# 690              negative              negative              NO
# 691              negative              negative              NO
# 692              Positive              Positive             YES
# 693              Positive              Positive             YES
# 694              negative              negative             YES
# 700              negative              negative             YES
# 709              negative              negative             YES
# 730              negative              negative             YES
# 731              negative              negative             YES
# 732              negative              negative             YES
# 768              negative              negative              NO
# 770              negative              negative             YES
# 804              Positive              Positive              NO
# 812              Positive              Positive              NO
# 833              negative              negative              NO
# 841              negative              negative              NO
# 842              negative              negative              NO
# 877              negative              negative             YES
# 911              negative              negative              NO
# 917              negative              negative              NO
# 927              negative              negative              NO
# 929              negative              negative              NO
#
#                                       ...                                     \
# 190                                   ...
# 198                                   ...
# 199                                   ...
# 245                                   ...
# 295                                   ...
# 297                                   ...
# 327                                   ...
# 331                                   ...
# 334                                   ...
# 357                                   ...
# 360                                   ...
# 375                                   ...
# 376                                   ...
# 377                                   ...
# 378                                   ...
# 391                                   ...
# 392                                   ...
# 393                                   ...
# 394                                   ...
# 395                                   ...
# 396                                   ...
# 397                                   ...
# 398                                   ...
# 399                                   ...
# 400                                   ...
# 401                                   ...
# 402                                   ...
# 403                                   ...
# 404                                   ...
# 405                                   ...
# ..                                    ...
# 682                                   ...
# 683                                   ...
# 684                                   ...
# 685                                   ...
# 686                                   ...
# 687                                   ...
# 688                                   ...
# 689                                   ...
# 690                                   ...
# 691                                   ...
# 692                                   ...
# 693                                   ...
# 694                                   ...
# 700                                   ...
# 709                                   ...
# 730                                   ...
# 731                                   ...
# 732                                   ...
# 768                                   ...
# 770                                   ...
# 804                                   ...
# 812                                   ...
# 833                                   ...
# 841                                   ...
# 842                                   ...
# 877                                   ...
# 911                                   ...
# 917                                   ...
# 927                                   ...
# 929                                   ...
#
#     Indirect     (mg/dl) Total Protein     (g/dl) Albumin   (g/dl)  \
# 190                  3.5                      3.0              1.4
# 198                  3.5                      3.0              1.4
# 199                  3.5                      3.0              1.4
# 245                  1.3                      6.8              3.0
# 295                  3.0                      6.0              3.0
# 297                  3.0                      6.0              3.0
# 327                  2.0                      7.0              2.1
# 331                  2.0                      7.6              5.4
# 334                  1.6                      7.4              2.6
# 357                  3.0                      6.2              2.5
# 360                  2.0                      5.8              2.2
# 375                  2.0                      6.4              1.9
# 376                  2.1                      7.0              2.1
# 377                  2.0                      6.4              1.9
# 378                  2.1                      7.0              2.1
# 391                  2.0                      6.4              1.9
# 392                  2.1                      7.0              2.1
# 393                  2.0                      6.4              1.9
# 394                  2.1                      7.0              2.1
# 395                  1.5                      5.0              2.5
# 396                  2.4                      4.0              2.0
# 397                  2.0                      6.0              3.2
# 398                  4.4                      5.6              1.6
# 399                  3.0                      6.1              1.6
# 400                  2.2                      7.1              2.0
# 401                  4.0                      4.0              0.9
# 402                  1.0                      5.0              3.0
# 403                  4.4                      4.0              1.5
# 404                  1.0                      4.0              2.0
# 405                  1.8                      5.0              2.0
# ..                   ...                      ...              ...
# 682                  3.0                      4.0              2.0
# 683                  3.0                      4.0              1.1
# 684                  2.5                      3.0              1.2
# 685                  3.0                      3.0              1.2
# 686                  3.6                      3.0              2.0
# 687                  0.6                      4.0              2.0
# 688                  4.0                      3.0              1.0
# 689                  1.2                      4.0              3.0
# 690                  3.0                      4.0              2.0
# 691                  3.0                      4.0              1.1
# 692                  2.5                      3.0              1.2
# 693                  3.0                      3.0              1.2
# 694                  3.6                      3.0              2.0
# 700                  2.7                      6.0              1.8
# 709                  0.9                      6.0              4.0
# 730                  1.4                      7.2              2.9
# 731                  3.0                      6.2              3.2
# 732                  2.4                      6.6              3.6
# 768                  1.2                      5.8              3.2
# 770                  3.7                      6.2              2.8
# 804                  1.5                      5.0              2.5
# 812                  1.5                      5.0              2.5
# 833                  0.4                      4.0              2.2
# 841                  0.4                      4.0              2.2
# 842                  0.4                      4.0              2.2
# 877                  NaN                      6.1              2.1
# 911                  3.0                      4.0              3.0
# 917                  3.0                      4.0              3.0
# 927                  3.0                      4.0              3.0
# 929                  3.0                      4.0              3.0
#
#      Globulin  (g/dl)            A/G Ratio AL.Phosphatase      (U/L)  \
# 190               1.6                  NaN                     114.0
# 198               1.6                  NaN                     114.0
# 199               1.6                  NaN                     114.0
# 245               3.8                 0.78                     122.0
# 295               4.0                 0.75                     115.0
# 297               4.0                 0.75                     115.0
# 327               3.9                  NaN                     140.0
# 331               2.2                 2.45                     137.0
# 334               4.8                  NaN                     126.0
# 357               3.1                  NaN                     124.0
# 360               3.6                  NaN                     140.0
# 375               4.6      00:01:02.200000                     206.0
# 376               4.9             01:02:00                     156.0
# 377               4.6                  NaN                     206.0
# 378               4.9                  NaN                     156.0
# 391               4.6      00:01:02.200000                     206.0
# 392               4.9             01:02:00                     156.0
# 393               4.6      00:01:02.200000                     206.0
# 394               4.9             01:02:00                     156.0
# 395               2.5             01:01:00                     152.0
# 396               2.0             01:01:00                     111.0
# 397               2.8      00:01:00.875000                     160.0
# 398               4.0      00:01:03.500000                      98.0
# 399               4.4             01:03:00                     106.0
# 400               5.1             01:03:00                      76.0
# 401               3.1             01:03:00                     184.0
# 402               2.0                1.5:1                      96.0
# 403               2.5                0.6:1                     102.0
# 404               2.0             01:01:00                     100.0
# 405               3.0                0.6:1                     100.0
# ..                ...                  ...                       ...
# 682               2.0             01:01:00                     104.0
# 683               3.0             01:03:00                      98.0
# 684               2.8             02:03:00                     180.0
# 685               1.8             02:03:00                     184.0
# 686               1.0             02:01:00                     114.0
# 687               2.0             01:01:00                     112.0
# 688               2.0             01:02:00                     112.0
# 689               1.0             03:01:00                     110.0
# 690               2.0             01:01:00                     104.0
# 691               3.0             01:03:00                      98.0
# 692               2.8             02:03:00                     180.0
# 693               1.8             02:03:00                     184.0
# 694               1.0             02:01:00                     114.0
# 700               2.5                 0.72                     156.0
# 709               2.0             02:01:00                     180.0
# 730               4.3                  NaN                     148.0
# 731               3.0                  NaN                     148.0
# 732               3.0                  NaN                     129.0
# 768               2.6                1.5:1                     119.0
# 770               3.1                  NaN                     117.0
# 804               2.5             01:01:00                     124.0
# 812               2.5             01:01:00                     124.0
# 833               2.0  1900-01-01 00:00:00                     100.0
# 841               2.0             01:01:00                     100.0
# 842               2.0             01:01:00                     100.0
# 877               4.3                 0.48                     130.0
# 911               1.0             03:01:00                     120.0
# 917               1.0             03:01:00                     120.0
# 927               1.0             03:01:00                     120.0
# 929               1.0             03:01:00                     120.0
#
#      SGOT/AST      (U/L)  SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)  \
# 190                  204             108                                  YES
# 198                  204             108                                  YES
# 199                  204             108                                  YES
# 245                   96              34                                  YES
# 295                   68              35                                  YES
# 297                   68              35                                  YES
# 327                   56              42                                  YES
# 331                   66              58                                  YES
# 334                   59              44                                  YES
# 357                   54              40                                  YES
# 360                  120              44                                  YES
# 375                  142             116                                  YES
# 376                   76              49                                  YES
# 377                  142             116                                  YES
# 378                   76              49                                  YES
# 391                  142             116                                  YES
# 392                   76              49                                  YES
# 393                  142             116                                  YES
# 394                   76              49                                  YES
# 395                  172             180                                  YES
# 396                  104              74                                  YES
# 397                   75              82                                  YES
# 398                   32              23                                  YES
# 399                   66              41                                  YES
# 400                   59              48                                  YES
# 401                  112              97                                  YES
# 402                   90              60                                  YES
# 403                   94              86                                  YES
# 404                   94             106                                  YES
# 405                   96              94                                  YES
# ..                   ...             ...                                  ...
# 682                  102              72                                  YES
# 683                   74              42                                  YES
# 684                  200             106                                  YES
# 685                   72              40                                  YES
# 686                   70              72                                  YES
# 687                  100              60                                  YES
# 688                   74              40                                  YES
# 689                   70              40                                  YES
# 690                  102              72                                  YES
# 691                   74              42                                  YES
# 692                  200             106                                  YES
# 693                   72              40                                  YES
# 694                   70              72                                  YES
# 700                   67              58                                  YES
# 709                   84              96                                  YES
# 730                   76              48                                  YES
# 731                   68              24                                  YES
# 732                   66              38                                  YES
# 768                   54              46                                  YES
# 770                   56              48                                  YES
# 804                  110              70                                  YES
# 812                  110              70                                  YES
# 833                   72              60                                  YES
# 841                   72              60                                  YES
# 842                   72              60                                  YES
# 877                   56              48                                  YES
# 911                  110              70                                   no
# 917                  110              70                                   no
# 927                  110              70                                   no
# 929                  110              70                                   no
#
#      Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# 190                                                NaN
# 198                                                YES
# 199                                                YES
# 245                                                YES
# 295                                                YES
# 297                                                YES
# 327                                                YES
# 331                                                YES
# 334                                                YES
# 357                                                YES
# 360                                                YES
# 375                                                NaN
# 376                                                NaN
# 377                                                YES
# 378                                                YES
# 391                                                YES
# 392                                                YES
# 393                                                YES
# 394                                                YES
# 395                                                NaN
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
# 402                                                NaN
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# ..                                                 ...
# 682                                                YES
# 683                                                YES
# 684                                                YES
# 685                                                YES
# 686                                                YES
# 687                                                YES
# 688                                                YES
# 689                                                YES
# 690                                                YES
# 691                                                YES
# 692                                                YES
# 693                                                YES
# 694                                                YES
# 700                                                YES
# 709                                                YES
# 730                                                YES
# 731                                                YES
# 732                                                YES
# 768                                                YES
# 770                                                YES
# 804                                                NaN
# 812                                                YES
# 833                                                NaN
# 841                                                YES
# 842                                                YES
# 877                                                YES
# 911                                                NaN
# 917                                                YES
# 927                                                YES
# 929                                                YES
#
# [134 rows x 42 columns]

# %% [markdown]
# ### 10. Change place to urban if gender is female else rural

# %%
hc_df.loc[((hc_df['Gender']=='female')),"Place"]='rural'
hc_df.loc[((hc_df['Gender']=='male')),"Place"]='urban'
hc_df[hc_df.Place.isnull()]
# Out:
# Empty DataFrame
# Columns: [S.NO, Age, Gender, Place, Duration of alcohol consumption(years), Quantity of alcohol consumption (quarters/day), Type of alcohol consumed, Hepatitis B infection, Hepatitis C infection, Diabetes Result, Blood pressure (mmhg), Obesity, Family history of cirrhosis/ hereditary, TCH, TG, LDL, HDL, Hemoglobin  (g/dl), PCV  (%), RBC  (million cells/microliter), MCV   (femtoliters/cell), MCH  (picograms/cell), MCHC  (grams/deciliter), Total Count, Polymorphs  (%) , Lymphocytes  (%), Monocytes   (%), Eosinophils   (%), Basophils  (%), Platelet Count  (lakhs/mm), Total Bilirubin    (mg/dl), Direct    (mg/dl), Indirect     (mg/dl), Total Protein     (g/dl), Albumin   (g/dl), Globulin  (g/dl), A/G Ratio, AL.Phosphatase      (U/L), SGOT/AST      (U/L), SGPT/ALT (U/L), USG Abdomen (diffuse liver or  not), Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)]
# Index: []
#
# [0 rows x 42 columns]
